# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities, color = "b")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>

# %%
# Create the ticks for our bar chart's x axis
ticks = [i for i in x_axis]
plt.xticks(ticks,cities)
# Out:
# ([<matplotlib.axis.XTick at 0x161e350ad88>,
#   <matplotlib.axis.XTick at 0x161e3518fc8>,
#   <matplotlib.axis.XTick at 0x161e6f95f88>,
#   <matplotlib.axis.XTick at 0x161e6fa7888>,
#   <matplotlib.axis.XTick at 0x161e6fa7fc8>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-1,5)
# Out:
# (-1.0, 5.0)

# %%
# Set the limits of the y axis
plt.ylim(0,max(bars_in_cities)+0.5)
# Out:
# (0.0, 9.1)

# %%
# Give the chart a title, x label, and y label
plt.xlabel("Cities")
plt.ylable("No. of bars")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-d26c4e5f064d> in <module>
#       1 # Give the chart a title, x label, and y label
#       2 plt.xlabel("Cities")
# ----> 3 plt.ylable("No. of bars")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
# Save an image of the chart and print it to the screen
plt.savefig("barsincities.png")
